# %%
import pandas as pd

# %%
list(pd.read_csv("WEC_Perth_49.csv").columns)
# Out:
# ['X1',
#  'Y1',
#  'X2',
#  'Y2',
#  'X3',
#  'Y3',
#  'X4',
#  'Y4',
#  'X5',
#  'Y5',
#  'X6',
#  'Y6',
#  'X7',
#  'Y7',
#  'X8',
#  'Y8',
#  'X9',
#  'Y9',
#  'X10',
#  'Y10',
#  'X11',
#  'Y11',
#  'X12',
#  'Y12',
#  'X13',
#  'Y13',
#  'X14',
#  'Y14',
#  'X15',
#  'Y15',
#  'X16',
#  'Y16',
#  'X17',
#  'Y17',
#  'X18',
#  'Y18',
#  'X19',
#  'Y19',
#  'X20',
#  'Y20',
#  'X21',
#  'Y21',
#  'X22',
#  'Y22',
#  'X23',
#  'Y23',
#  'X24',
#  'Y24',
#  'X25',
#  'Y25',
#  'X26',
#  'Y26',
#  'X27',
#  'Y27',
#  'X28',
#  'Y28',
#  'X29',
#  'Y29',
#  'X30',
#  'Y30',
#  'X31',
#  'Y31',
#  'X32',
#  'Y32',
#  'X33',
#  'Y33',
#  'X34',
#  'Y34',
#  'X35',
#  'Y35',
#  'X36',
#  'Y36',
#  'X37',
#  'Y37',
#  'X38',
#  'Y38',
#  'X39',
#  'Y39',
#  'X40',
#  'Y40',
#  'X41',
#  'Y41',
#  'X42',
#  'Y42',
#  'X43',
#  'Y43',
#  'X44',
#  'Y44',
#  'X45',
#  'Y45',
#  'X46',
#  'Y46',
#  'X47',
#  'Y47',
#  'X48',
#  'Y48',
#  'X49',
#  'Y49',
#  'Power1',
#  'Power2',
# ...

# %%
cont_vars = [f"X{i}" for i in range(1,50)]+[f"Y{i}" for i in range(1,50)]

# %%
cont_vars
# Out:
# ['X1',
#  'X2',
#  'X3',
#  'X4',
#  'X5',
#  'X6',
#  'X7',
#  'X8',
#  'X9',
#  'X10',
#  'X11',
#  'X12',
#  'X13',
#  'X14',
#  'X15',
#  'X16',
#  'X17',
#  'X18',
#  'X19',
#  'X20',
#  'X21',
#  'X22',
#  'X23',
#  'X24',
#  'X25',
#  'X26',
#  'X27',
#  'X28',
#  'X29',
#  'X30',
#  'X31',
#  'X32',
#  'X33',
#  'X34',
#  'X35',
#  'X36',
#  'X37',
#  'X38',
#  'X39',
#  'X40',
#  'X41',
#  'X42',
#  'X43',
#  'X44',
#  'X45',
#  'X46',
#  'X47',
#  'X48',
#  'X49',
#  'Y1',
#  'Y2',
#  'Y3',
#  'Y4',
#  'Y5',
#  'Y6',
#  'Y7',
#  'Y8',
#  'Y9',
#  'Y10',
#  'Y11',
#  'Y12',
#  'Y13',
#  'Y14',
#  'Y15',
#  'Y16',
#  'Y17',
#  'Y18',
#  'Y19',
#  'Y20',
#  'Y21',
#  'Y22',
#  'Y23',
#  'Y24',
#  'Y25',
#  'Y26',
#  'Y27',
#  'Y28',
#  'Y29',
#  'Y30',
#  'Y31',
#  'Y32',
#  'Y33',
#  'Y34',
#  'Y35',
#  'Y36',
#  'Y37',
#  'Y38',
#  'Y39',
#  'Y40',
#  'Y41',
#  'Y42',
#  'Y43',
#  'Y44',
#  'Y45',
#  'Y46',
#  'Y47',
#  'Y48',
#  'Y49']
